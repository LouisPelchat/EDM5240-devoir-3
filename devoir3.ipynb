# %% [markdown]
# # Devoir 3 : Demandes d'accès à l'information

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
pd.set_option("display.float_format", lambda x : "%.2f" % x)

# %%
info = pd.read_csv("ati.csv")

# %%
info
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2015      4   A-2015-00001
# 2      2015      4   A-2014-00219
# 3      2015      4   A-2014-00218
# 4      2015      4   A-2014-00217
# 5      2015      4   A-2014-00216
# 6      2015      4   A-2014-00214
# 7      2015      4   A-2014-00210
# 8      2015      4   A-2014-00213
# 9      2015      6   A-2015-00012
# 10     2015      4   A-2014-00212
# 11     2015      4   A-2014-00200
# 12     2015      4   A-2014-00140
# 13     2015      5   A-2015-00003
# 14     2015      4   A-2014-00112
# 15     2015      5   A-2014-00211
# 16     2015      4   A-2014-00098
# 17     2015      4   A-2014-00070
# 18     2015      4   A-2015-00009
# 19     2015      5   A-2015-00011
# 20     2015      5   A-2015-00010
# 21     2015      5   A-2015-00006
# 22     2015      5   A-2014-00209
# 23     2015      5   A-2014-00145
# 24     2015      5   A-2014-00137
# 25     2015      5   A-2014-00134
# ...

# %% [markdown]
# Cellule#1 ci dessous: Elle nous apprend la moyenne de page que contient une demande d'accès à l'information depuis 2015

# %%
info.pages.value_counts().mean()
# Out:
# 17.407384987893462

# %% [markdown]
# Cellule#2 ci-dessous: Elle nous apprends le nombre de demande faite selon le mois de l'année. On voit ici que les demandes par mois se ressemble passablement, excluant les deux premiers mois de l'années, où on constate beaucoup moins de demande. Force est aussi de constater qu'il existe maintenant un 13ème et un 55ème mois de l'année.

# %%
info.month.value_counts()
# Out:
# 6     2718
# 3     2648
# 5     2612
# 7     2601
# 9     2579
# 10    2537
# 11    2504
# 12    2460
# 8     2382
# 4     2315
# 1     1951
# 2     1404
# 0       44
# 13       1
# 55       1
# Name: month, dtype: int64

# %% [markdown]
# Cellule#3 Nous permet de voir combien de demande on été faite par années depuis 2015. On apprend donc qu'il y a eu près de 2500 demande de plus en 2016 qu'en 2015. Il faut cependant ignorer la donnée de 2017, car l'année est tout juste entammée.

# %%
info.year.value_counts().plot(kind="bar", title="Demandes d'accès à l'information par année")
